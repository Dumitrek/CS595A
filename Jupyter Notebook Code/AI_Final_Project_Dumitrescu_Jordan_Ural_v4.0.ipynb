# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import json
import requests
import os
from decimal import Decimal

# %%
df_userP = pd.read_json('user_json.json')
df_userP.shape
# Out:
# (60, 16)

# %%
df_userP.head()
# Out:
#                        id                           title  \
# 0  1DunhgeZSEgWiIYbHqXl0c                           Latch
# 1  52xJxFP6TqMuO4Yt0eOkMz       We Don't Talk About Bruno
# 2  7oOOI85fVQvVnK5ynNMdW7  Rock with You - Single Version
# 3  7ruiupyTfOflj8JSHCG6vL                         Go Gina
# 4  0rFOs9paloAvEtzwDX1Kmc                          Bubbly
#
#                  first_artist  \
# 0                  Disclosure
# 1  Carolina Gaitán - La Gaita
# 2             Michael Jackson
# 3                         SZA
# 4              Colbie Caillat
#
#                                          all_artists  danceability  energy  \
# 0                            [Disclosure, Sam Smith]         0.729   0.735
# 1  [Carolina Gaitán - La Gaita, Mauro Castillo, A...         0.577   0.450
# 2                                  [Michael Jackson]         0.808   0.535
# 3                                              [SZA]         0.569   0.610
# 4                                   [Colbie Caillat]         0.697   0.474
#
#    key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0    1    -5.455     1        0.0178          0.000193     0.089    0.544
# 1    0    -8.516     0        0.3570          0.000000     0.111    0.830
# 2    1   -12.521     1        0.1790          0.000099     0.158    0.848
# 3    6    -6.105     0        0.7840          0.000000     0.392    0.413
# 4    9    -6.663     1        0.6030          0.000000     0.110    0.249
#
#      tempo  duration_ms  time_signature
# 0  121.986       255867               4
# 1  205.863       216120               4
# 2  114.031       220627               4
# 3   79.680       161613               4
# 4  127.904       196280               4

# %%
display(df_userP)
# Out:
#                         id                                       title  \
# 0   1DunhgeZSEgWiIYbHqXl0c                                       Latch
# 1   52xJxFP6TqMuO4Yt0eOkMz                   We Don't Talk About Bruno
# 2   7oOOI85fVQvVnK5ynNMdW7              Rock with You - Single Version
# 3   7ruiupyTfOflj8JSHCG6vL                                     Go Gina
# 4   0rFOs9paloAvEtzwDX1Kmc                                      Bubbly
# 5   0MSJk0VWUxAGat5vhJ4q4N                                       A-O-K
# 6   6x4tKaOzfNJpEJHySoiJcs            Mambo No. 5 (a Little Bit of...)
# 7   10ImcQk9tihY1EKMDIbvXJ                                 To Be Loved
# 8   6M47gaKejso9772SKTa3yH                                    Face Off
# 9   5JCoSi02qi3jJeHdZXMmR8                              favorite crime
# 10  2stPxcgjdSImK7Gizl8ZUN                                     The Man
# 11  6N22FZs2ZhPBYi3b9XPajV                    Still Don't Know My Name
# 12  77j9HOrxUpWcjwra9jgvio  We like to Party! (The Vengabus) Six Flags
# 13  0KOE1hat4SIer491XKk4Pa                      A Change Is Gonna Come
# 14  5OMpHNgfclfIIgT4FBzHty                                   Psalm 150
# 15  1GJKuRlblj551gKHghS2xo                               I Am Changing
# 16  47cQCF21TczFSmGfpd7c07                                          EX
# 17  5NaM1Pvh51i5Ja5EMb7D31                                        Time
# 18  3H4ZrsDezaN37zplSpXUWd                               Humpty Dumpty
# 19  0u2P5u6lvoDfwTYjAADbn4                        lovely (with Khalid)
# 20  5Z3GHaZ6ec9bsiI5BenrbY                          Young Dumb & Broke
# 21  5lXY6PTuWXOludKy4zDQwM                                  On My Mind
# 22  6KI1ZpZWYAJLvmVhCJz65G             You Don't Own Me (feat. G-Eazy)
# 23  5VnDkUNyX6u5Sk0yZiP8XB                                     Thunder
# 24  5yorXJWdBan1Vlh116ZtQ7                           WHOLE LOTTA MONEY
# 25  2bJvI42r8EF3wxjOuDav4r                           Time of Our Lives
# 26  6hmhG1b4LEyNuashVvuIAo                            Never Forget You
# 27  32OlwWuMpZ6b0aN2RZOeMS              Uptown Funk (feat. Bruno Mars)
# 28  6od5hFv9IT5JHc7NEF9HRv                                  Victorious
# 29  7ef4DlsgrMEH11cDZd32M6                    One Kiss (with Dua Lipa)
# 30  2IpGdrWvIZipmaxo1YRxw5              Bottoms Up (feat. Nicki Minaj)
# 31  6b8Be6ljOzmkOmFslEb23P                                   24K Magic
# 32  1G7DcLzPnopdZjLkev0K4e                               Irreplaceable
# 33  2MAyGB3UgAbbT1Fjc7b7aA                       Deja Vu (feat. Jay-Z)
# 34  56mAv6TVHL4QXcD4B4Ezvg       Check On It (feat. Bun B & Slim Thug)
# 35  0IkKz2J93C94Ei4BvDop7P                           Party Rock Anthem
# 36  5OiLJ8tjUPFiPX2gVM8fxJ                                     Imma Be
# 37  67awxiNHNyjMXhVgsHuIrs                          Turn Down for What
# 38  6uQKuonTU8VKBz5SHZuQXD                        This Is How We Do It
# 39  6o3s08kk2fQI37vxGZDrJ1                             Snap Yo Fingers
# 40  3Dv1eDb0MEgF93GpLXlucZ                                      Say So
# 41  78qd8dvwea0Gosb6Fe6j3k                                  Boss Bitch
# 42  1Cv1YLb4q0RzL6pybtaMLo                                 Sunday Best
# 43  3VygfAvvgVaJUeaBUSzlZu                                       Karma
# 44  4byXh93siQtzKLdjKuJaAF                                     No Plan
# 45  0dfQwyoZoS9LgQiU6AJO7f                              100% Pure Love
# 46  3sBdf3nxnEC9e2GcdP9d3j   Ordinaryish People (feat. Blue Man Group)
# 47  7MAibcTli4IisCtbHKrGMh                         Leave The Door Open
# 48  4iJyoBOLtHqaGxP12qzhQI      Peaches (feat. Daniel Caesar & Giveon)
# 49  6FE2iI43OZnszFLuLtvvmg                                     Classic
# 50  07Tx168RSsUS1HqkDIOZbH                               Cupid Shuffle
# 51  6epn3r7S14KUqlReYr77hA                                        Baby
# 52  0BBLIc1LYjA5yNsD1t6Fp5              Time of Our Lives - Radio Edit
# 53  7y3xU9vEC1s8DSuuoSYKih                              Been Like This
# 54  5FQPpxOXsvkMN6v18gtpwY                                       Bang!
# 55  5cBLBXhU9sf6kGvb2Dv2cl                               The Good Part
# 56  0TkJIyL69RAUIbNwGub6uR                         Burn The House Down
# 57  1bRjwdtScY2eMe9uMmsOkG                                       Do It
# 58  1zi7xx7UVEFkmKfv06H8x0                                   One Dance
# 59  3avYqdwHKEq8beXbeWCKqJ                Last Friday Night (T.G.I.F.)
#
#                   first_artist  \
# 0                   Disclosure
# 1   Carolina Gaitán - La Gaita
# 2              Michael Jackson
# 3                          SZA
# 4               Colbie Caillat
# 5                   Tai Verdes
# 6                     Lou Bega
# 7                        Adele
# 8                    Tech N9ne
# 9               Olivia Rodrigo
# 10                  Aloe Blacc
# 11                    Labrinth
# 12                   Vengaboys
# 13                   Sam Cooke
# 14                  James Moss
# 15             Jennifer Hudson
# 16                  Kiana Ledé
# 17            Sebastian Mikael
# 18                         AJR
# 19               Billie Eilish
# 20                      Khalid
# 21                       Diplo
# 22                    SAYGRACE
# 23             Imagine Dragons
# 24                         BIA
# 25                     Pitbull
# 26                Zara Larsson
# 27                 Mark Ronson
# 28         Panic! At The Disco
# 29               Calvin Harris
# 30                  Trey Songz
# 31                  Bruno Mars
# 32                     Beyoncé
# 33                     Beyoncé
# 34                     Beyoncé
# 35                       LMFAO
# 36             Black Eyed Peas
# 37                    DJ Snake
# 38              Montell Jordan
# 39                     Lil Jon
# 40                    Doja Cat
# 41                    Doja Cat
# 42                    Surfaces
# 43                         AJR
# 44                      Hozier
# 45              Crystal Waters
# 46                         AJR
# 47                  Bruno Mars
# 48               Justin Bieber
# 49                        MKTO
# 50                       Cupid
# 51               Justin Bieber
# 52                     Pitbull
# 53                    Doja Cat
# 54                         AJR
# 55                         AJR
# 56                         AJR
# 57               Chloe x Halle
# 58                       Drake
# 59                  Katy Perry
#
#                                           all_artists  danceability  energy  \
# 0                             [Disclosure, Sam Smith]         0.729   0.735
# 1   [Carolina Gaitán - La Gaita, Mauro Castillo, A...         0.577   0.450
# 2                                   [Michael Jackson]         0.808   0.535
# 3                                               [SZA]         0.569   0.610
# 4                                    [Colbie Caillat]         0.697   0.474
# 5                                        [Tai Verdes]         0.729   0.636
# 6                                          [Lou Bega]         0.622   0.807
# 7                                             [Adele]         0.356   0.176
# 8    [Tech N9ne, Joey Cool, King Iso, Dwayne Johnson]         0.693   0.935
# 9                                    [Olivia Rodrigo]         0.369   0.272
# 10                                       [Aloe Blacc]         0.308   0.769
# 11                                         [Labrinth]         0.316   0.630
# 12                                        [Vengaboys]         0.785   0.931
# 13                                        [Sam Cooke]         0.212   0.383
# 14                                       [James Moss]         0.708   0.897
# 15                                  [Jennifer Hudson]         0.550   0.483
# 16                                       [Kiana Ledé]         0.763   0.537
# 17                                 [Sebastian Mikael]         0.549   0.792
# 18                                              [AJR]         0.577   0.542
# 19                            [Billie Eilish, Khalid]         0.351   0.296
# 20                                           [Khalid]         0.799   0.539
# 21                                 [Diplo, SIDEPIECE]         0.771   0.731
# 22                                 [SAYGRACE, G-Eazy]         0.332   0.635
# 23                                  [Imagine Dragons]         0.604   0.826
# 24                                              [BIA]         0.897   0.371
# 25                                   [Pitbull, Ne-Yo]         0.721   0.802
# 26                               [Zara Larsson, MNEK]         0.583   0.732
# 27                          [Mark Ronson, Bruno Mars]         0.856   0.609
# 28                              [Panic! At The Disco]         0.570   0.865
# 29                          [Calvin Harris, Dua Lipa]         0.791   0.862
# 30                          [Trey Songz, Nicki Minaj]         0.845   0.601
# 31                                       [Bruno Mars]         0.818   0.803
# 32                                          [Beyoncé]         0.576   0.697
# 33                                   [Beyoncé, JAY-Z]         0.763   0.728
# 34                        [Beyoncé, Bun B, Slim Thug]         0.707   0.881
# 35                  [LMFAO, Lauren Bennett, GoonRock]         0.750   0.727
# 36                                  [Black Eyed Peas]         0.597   0.517
# 37                                [DJ Snake, Lil Jon]         0.818   0.799
# 38                             [Montell Jordan, Wino]         0.799   0.623
# 39                         [Lil Jon, E-40, Sean Paul]         0.835   0.757
# 40                                         [Doja Cat]         0.787   0.673
# 41                                         [Doja Cat]         0.707   0.955
# 42                                         [Surfaces]         0.878   0.525
# 43                                              [AJR]         0.528   0.727
# 44                                           [Hozier]         0.456   0.750
# 45                                   [Crystal Waters]         0.811   0.725
# 46                              [AJR, Blue Man Group]         0.627   0.640
# 47           [Bruno Mars, Anderson .Paak, Silk Sonic]         0.586   0.616
# 48             [Justin Bieber, Daniel Caesar, Giveon]         0.677   0.696
# 49                                             [MKTO]         0.720   0.791
# 50                                            [Cupid]         0.785   0.582
# 51                          [Justin Bieber, Ludacris]         0.728   0.859
# 52                                   [Pitbull, Ne-Yo]         0.714   0.706
# 53                                         [Doja Cat]         0.678   0.531
# 54                                              [AJR]         0.740   0.517
# 55                                              [AJR]         0.491   0.480
# 56                                              [AJR]         0.454   0.660
# 57                                    [Chloe x Halle]         0.701   0.668
# 58                              [Drake, WizKid, Kyla]         0.792   0.625
# 59                                       [Katy Perry]         0.652   0.812
#
#     key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0     1    -5.455     1       0.01780          0.000193    0.0890   0.5440
# 1     0    -8.516     0       0.35700          0.000000    0.1110   0.8300
# 2     1   -12.521     1       0.17900          0.000099    0.1580   0.8480
# 3     6    -6.105     0       0.78400          0.000000    0.3920   0.4130
# 4     9    -6.663     1       0.60300          0.000000    0.1100   0.2490
# 5     1    -6.487     0       0.15800          0.000000    0.2130   0.8110
# 6     5    -6.752     0       0.10300          0.000000    0.3060   0.8920
# 7     8    -8.291     1       0.84300          0.000000    0.2310   0.2890
# 8     8    -4.323     1       0.18000          0.000000    0.1790   0.3910
# 9     9   -10.497     1       0.86600          0.000000    0.1470   0.2180
# 10   11    -7.256     0       0.03310          0.000000    0.2140   0.4880
# 11    5    -5.963     1       0.47100          0.262000    0.2050   0.3130
# 12    8    -4.813     1       0.01480          0.637000    0.0459   0.9690
# 13   10   -10.071     1       0.72300          0.000000    0.2990   0.4520
# 14    1    -5.063     0       0.19100          0.000000    0.3940   0.8050
# 15   10    -6.140     1       0.12000          0.000000    0.3240   0.3210
# 16    9    -7.018     0       0.23100          0.000000    0.1090   0.4260
# 17    3    -6.279     1       0.45200          0.000000    0.0954   0.5630
# 18    0    -7.868     1       0.01020          0.000000    0.0778   0.4860
# 19    4   -10.109     0       0.93400          0.000000    0.0950   0.1200
# 20    1    -6.351     1       0.19900          0.000017    0.1650   0.3940
# 21    7    -6.574     1       0.00165          0.633000    0.2170   0.6350
# 22    7    -5.653     1       0.15900          0.000003    0.0599   0.2610
# 23    0    -4.804     1       0.00782          0.150000    0.1540   0.2410
# 24    1    -5.019     1       0.09040          0.000000    0.3250   0.4410
# 25    1    -5.797     1       0.09210          0.000000    0.6940   0.7240
# 26   11    -5.728     0       0.00312          0.000010    0.2690   0.2760
# 27    0    -7.223     1       0.00801          0.000082    0.0344   0.9280
# 28    8    -4.518     1       0.00205          0.000000    0.4040   0.6910
# 29    9    -3.240     0       0.03700          0.000022    0.0814   0.5920
# 30    1    -5.283     1       0.02050          0.000000    0.3850   0.3290
# 31    1    -4.282     1       0.03400          0.000000    0.1530   0.6320
# 32   10    -4.192     1       0.02860          0.000001    0.1670   0.5010
# 33    7    -4.944     1       0.00677          0.000012    0.0915   0.3620
# 34    7    -4.066     1       0.07820          0.000000    0.3880   0.9220
# 35    5    -4.210     0       0.01890          0.000000    0.2660   0.3590
# 36    0    -6.963     1       0.17900          0.000000    0.3070   0.4120
# 37    1    -4.100     0       0.00107          0.128000    0.0570   0.0815
# 38    0    -9.374     1       0.01410          0.000000    0.4300   0.7730
# 39    8    -5.029     0       0.00647          0.000000    0.2900   0.6260
# 40   11    -4.583     0       0.26400          0.000003    0.0904   0.7790
# 41   10    -4.593     0       0.12700          0.000000    0.2020   0.5750
# 42    5    -6.832     1       0.18300          0.000000    0.0714   0.6940
# 43    6    -5.739     1       0.05570          0.000000    0.1760   0.2120
# 44    9    -4.609     0       0.11500          0.000017    0.1140   0.5640
# 45    8    -7.203     1       0.08430          0.005900    0.0567   0.6980
# 46    8    -7.312     1       0.06040          0.000006    0.1250   0.8310
# 47    5    -7.964     1       0.18200          0.000000    0.0927   0.7190
# 48    0    -6.181     1       0.32100          0.000000    0.4200   0.4640
# 49    1    -4.689     1       0.03840          0.000000    0.1570   0.7560
# 50    5    -4.877     0       0.19100          0.000000    0.2000   0.8610
# 51    5    -5.237     0       0.04010          0.000000    0.1110   0.5350
# 52    1    -9.144     1       0.09460          0.000000    0.7000   0.8120
# 53   10    -5.029     1       0.12600          0.000034    0.3770   0.1760
# 54    1    -6.233     0       0.01830          0.000000    0.0558   0.6980
# 55    2    -3.568     0       0.08660          0.000032    0.3820   0.5520
# 56    0    -4.357     1       0.03640          0.000000    0.1810   0.5680
# 57    5    -7.287     0       0.09160          0.000002    0.1110   0.5530
# 58    1    -5.609     1       0.00776          0.001800    0.3290   0.3700
# 59    3    -3.797     0       0.00125          0.000030    0.6670   0.7200
#
#       tempo  duration_ms  time_signature
# 0   121.986       255867               4
# 1   205.863       216120               4
# 2   114.031       220627               4
# 3    79.680       161613               4
# 4   127.904       196280               4
# 5    82.498       173640               4
# 6   174.060       220293               4
# 7   170.425       403962               1
# 8    80.882       219802               4
# 9   172.929       152667               4
# 10   81.853       254880               4
# 11   89.643       153294               1
# 12  135.986       222459               4
# 13  173.790       191160               3
# 14  112.692       261960               4
# 15   82.435       242973               3
# 16   73.510       222387               4
# 17  134.824       210909               4
# 18   86.990       217703               4
# 19  115.284       200186               4
# 20  136.948       202547               4
# 21  123.026       189268               4
# 22  186.249       201493               3
# 23  167.985       187147               4
# 24   81.008       156005               4
# 25  124.022       229360               4
# 26  145.992       213428               4
# 27  114.988       269667               4
# 28  110.010       178600               4
# 29  123.994       214847               4
# 30   74.008       242013               4
# 31  106.970       225983               4
# 32  175.906       227667               4
# 33  105.923       239960               4
# 34  166.020       210707               4
# 35  129.993       262173               4
# 36   92.035       257560               4
# 37  100.014       213733               4
# 38  103.649       238800               4
# 39   82.038       274387               4
# 40  110.962       237893               4
# 41  125.989       134240               4
# 42  112.022       158571               4
# 43  155.927       245270               4
# 44   80.019       331013               4
# 45  120.242       278627               4
# 46  179.819       219995               4
# 47  148.088       242096               4
# 48   90.030       198082               4
# 49  102.071       175427               4
# 50   71.774       231360               4
# 51   65.043       214240               4
# 52  124.036       214080               4
# 53   99.008       177373               4
# 54  139.917       170858               4
# 55   92.919       227267               4
# 56  184.353       212374               4
# 57   82.978       176787               4
# 58  103.967       173987               4
# 59  126.023       230733               4

# %%
df_userP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                60 non-null     object
#  1   title             60 non-null     object
#  2   first_artist      60 non-null     object
#  3   all_artists       60 non-null     object
#  4   danceability      60 non-null     float64
#  5   energy            60 non-null     float64
#  6   key               60 non-null     int64
#  7   loudness          60 non-null     float64
#  8   mode              60 non-null     int64
#  9   acousticness      60 non-null     float64
#  10  instrumentalness  60 non-null     float64
#  11  liveness          60 non-null     float64
#  12  valence           60 non-null     float64
#  13  tempo             60 non-null     float64
#  14  duration_ms       60 non-null     int64
#  15  time_signature    60 non-null     int64
# dtypes: float64(8), int64(4), object(4)
# memory usage: 8.0+ KB

# %%
df_userP.describe()
# Out:
#        danceability     energy        key   loudness       mode  acousticness  \
# count     60.000000  60.000000  60.000000  60.000000  60.000000     60.000000
# mean       0.653533   0.658883   4.833333  -6.139717   0.633333      0.173051
# std        0.161532   0.168497   3.760484   1.881999   0.485961      0.235981
# min        0.212000   0.176000   0.000000 -12.521000   0.000000      0.001070
# 25%        0.574500   0.538500   1.000000  -7.064250   0.000000      0.018750
# 50%        0.704000   0.670500   5.000000  -5.768000   1.000000      0.091000
# 75%        0.785000   0.791250   8.000000  -4.775250   1.000000      0.185000
# max        0.897000   0.955000  11.000000  -3.240000   1.000000      0.934000
#
#        instrumentalness   liveness    valence       tempo    duration_ms  \
# count         60.000000  60.000000  60.000000   60.000000      60.000000
# mean           0.030304   0.222538   0.545758  119.720500  218073.333333
# std            0.120657   0.156626   0.227084   34.990282   43764.851359
# min            0.000000   0.034400   0.081500   65.043000  134240.000000
# 25%            0.000000   0.105600   0.368000   89.933250  190687.000000
# 50%            0.000000   0.177500   0.552500  114.509500  216911.500000
# 75%            0.000017   0.311250   0.721000  137.690250  239090.000000
# max            0.637000   0.700000   0.969000  205.863000  403962.000000
#
#        time_signature
# count       60.000000
# mean         3.850000
# std          0.577106
# min          1.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000

# %%
df_userP.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_f92ac_row0_col0, #T_f92ac_row1_col1, #T_f92ac_row2_col2, #T_f92ac_row3_col3, #T_f92ac_row4_col4, #T_f92ac_row5_col5, #T_f92ac_row6_col6, #T_f92ac_row7_col7, #T_f92ac_row8_col8, #T_f92ac_row9_col9, #T_f92ac_row10_col10, #T_f92ac_row11_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f92ac_row0_col1 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_f92ac_row0_col2, #T_f92ac_row0_col9, #T_f92ac_row1_col5, #T_f92ac_row2_col7, #T_f92ac_row3_col4, #T_f92ac_row5_col0, #T_f92ac_row5_col1, #T_f92ac_row5_col3, #T_f92ac_row5_col8, #T_f92ac_row5_col11, #T_f92ac_row7_col6, #T_f92ac_row11_col4, #T_f92ac_row11_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f92ac_row0_col3 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_f92ac_row0_col4, #T_f92ac_row4_col11, #T_f92ac_row9_col6 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_f92ac_row0_col5, #T_f92ac_row1_col4, #T_f92ac_row2_col4, #T_f92ac_row9_col7 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_f92ac_row0_col6, #T_f92ac_row1_col9, #T_f92ac_row3_col10, #T_f92ac_row4_col8 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_f92ac_row0_col7, #T_f92ac_row1_col10, #T_f92ac_row5_col10, #T_f92ac_row11_col7 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_f92ac_row0_col8 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_f92ac_row0_col10 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_f92ac_row0_col11 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_f92ac_row1_col0 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_f92ac_row1_col2 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_f92ac_row1_col3 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_f92ac_row1_col6, #T_f92ac_row10_col8 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_f92ac_row1_col7, #T_f92ac_row3_col8 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_f92ac_row1_col8 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_f92ac_row1_col11 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_f92ac_row2_col0, #T_f92ac_row4_col10 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f92ac_row2_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_f92ac_row2_col3, #T_f92ac_row6_col0 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_f92ac_row2_col5 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_f92ac_row2_col6 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_f92ac_row2_col8 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_f92ac_row2_col9, #T_f92ac_row6_col8 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_f92ac_row2_col10, #T_f92ac_row4_col6 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_f92ac_row2_col11, #T_f92ac_row7_col9, #T_f92ac_row7_col10, #T_f92ac_row8_col5, #T_f92ac_row11_col9 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_f92ac_row3_col0 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_f92ac_row3_col1 {
#   background-color: #2171b5;
#   color: #f1f1f1;
# }
# #T_f92ac_row3_col2, #T_f92ac_row6_col4 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_f92ac_row3_col5 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_f92ac_row3_col6 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_f92ac_row3_col7, #T_f92ac_row7_col4 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_f92ac_row3_col9 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_f92ac_row3_col11 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_f92ac_row4_col0 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_f92ac_row4_col1, #T_f92ac_row6_col2, #T_f92ac_row6_col9, #T_f92ac_row10_col2 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_f92ac_row4_col2 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_f92ac_row4_col3, #T_f92ac_row9_col10 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_f92ac_row4_col5 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_f92ac_row4_col7 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_f92ac_row4_col9, #T_f92ac_row11_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_f92ac_row5_col2, #T_f92ac_row7_col3 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_f92ac_row5_col4 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_f92ac_row5_col6 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f92ac_row5_col7, #T_f92ac_row8_col4 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_f92ac_row5_col9 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_f92ac_row6_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_f92ac_row6_col3 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_f92ac_row6_col5, #T_f92ac_row8_col9, #T_f92ac_row9_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_f92ac_row6_col7 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_f92ac_row6_col10, #T_f92ac_row7_col2, #T_f92ac_row11_col2 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_f92ac_row6_col11, #T_f92ac_row8_col6, #T_f92ac_row9_col11 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_f92ac_row7_col0, #T_f92ac_row10_col5 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_f92ac_row7_col1 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_f92ac_row7_col5 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_f92ac_row7_col8 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_f92ac_row7_col11 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_f92ac_row8_col0 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_f92ac_row8_col1 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_f92ac_row8_col2 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_f92ac_row8_col3 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_f92ac_row8_col7 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_f92ac_row8_col10 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_f92ac_row8_col11 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_f92ac_row9_col0, #T_f92ac_row11_col5 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_f92ac_row9_col2 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_f92ac_row9_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_f92ac_row9_col4 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_f92ac_row9_col5 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_f92ac_row9_col8, #T_f92ac_row10_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_f92ac_row10_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_f92ac_row10_col3 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_f92ac_row10_col4, #T_f92ac_row10_col7, #T_f92ac_row10_col11 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_f92ac_row10_col6 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_f92ac_row10_col9 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_f92ac_row11_col0 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_f92ac_row11_col1 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_f92ac_row11_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_f92ac_row11_col8 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# </style>
# <table id="T_f92ac_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >danceability</th>
#       <th class="col_heading level0 col1" >energy</th>
#       <th class="col_heading level0 col2" >key</th>
#       <th class="col_heading level0 col3" >loudness</th>
#       <th class="col_heading level0 col4" >mode</th>
#       <th class="col_heading level0 col5" >acousticness</th>
#       <th class="col_heading level0 col6" >instrumentalness</th>
#       <th class="col_heading level0 col7" >liveness</th>
#       <th class="col_heading level0 col8" >valence</th>
#       <th class="col_heading level0 col9" >tempo</th>
#       <th class="col_heading level0 col10" >duration_ms</th>
#       <th class="col_heading level0 col11" >time_signature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f92ac_level0_row0" class="row_heading level0 row0" >danceability</th>
#       <td id="T_f92ac_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_f92ac_row0_col1" class="data row0 col1" >0.32

# %%
df_spotR = pd.read_json('rec_json.json')
df_spotR.shape
# Out:
# (60, 16)

# %%
df_spotR.head()
# Out:
#                        id                                  title  \
# 0  1KtD0xaLAikgIt5tPbteZQ  Thinking About You (feat. Ayah Marar)
# 1  4b1yxSdlumA8N4fEk4UOZp                    The Family Madrigal
# 2  4E6cwWJWZw2zWf7VFbH7wf                              Love Song
# 3  1ts8KebAIm5xCiGInoWiqp                             Fine Apple
# 4  4Y6cDd4EPHcEbiUKdyvNwM                               Macarena
#
#         first_artist                                        all_artists  \
# 0      Calvin Harris                        [Calvin Harris, Ayah Marar]
# 1  Stephanie Beatriz  [Stephanie Beatriz, Olga Merediz, Encanto - Cast]
# 2     Sara Bareilles                                   [Sara Bareilles]
# 3              Nic D                                            [Nic D]
# 4        Los Del Rio                                      [Los Del Rio]
#
#    danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0         0.725   0.874    0    -3.715     0       0.00262          0.000412
# 1         0.594   0.628    1    -6.345     1       0.12000          0.000000
# 2         0.583   0.786    2    -3.142     0       0.02080          0.000000
# 3         0.925   0.558    2    -5.362     1       0.17800          0.000000
# 4         0.923   0.679    8   -14.019     1       0.42800          0.000131
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0    0.0958    0.748  127.985       247933               4
# 1    0.0582    0.556  141.391       257213               4
# 2    0.1880    0.573  123.055       258827               4
# 3    0.1250    0.467  119.992       153297               4
# 4    0.0908    0.965  103.017       251293               4

# %%
display(df_spotR)
# Out:
#                         id                                              title  \
# 0   1KtD0xaLAikgIt5tPbteZQ              Thinking About You (feat. Ayah Marar)
# 1   4b1yxSdlumA8N4fEk4UOZp                                The Family Madrigal
# 2   4E6cwWJWZw2zWf7VFbH7wf                                          Love Song
# 3   1ts8KebAIm5xCiGInoWiqp                                         Fine Apple
# 4   4Y6cDd4EPHcEbiUKdyvNwM                                           Macarena
# 5   6kUaRtXf19fu5IQWjmwsEJ                                      Venom - Remix
# 6   7a8GawTVgHZvBLQOh46he7                                   I Wanna Be Yours
# 7   4znJLBeXcOzPUg2mm5LfZV                         John Doe (feat. Priscilla)
# 8   7JDWhC422Gtk1Bq0mL3OTC                                     feel something
# 9   0HNXnhNZZtRZFLhP4hfyCP                               Hey Baby (Radio Mix)
# 10  2IkM8zrt6Y1F344CNfaDA0       A Change Is Gonna Come - Mono; 2008 Remaster
# 11  0YRRMpIFFuFf2Cq67s0fpm                                            But God
# 12  4g9p5kWDHAR3Vg2YRQwQDv                             I Know Where I've Been
# 13  2GlATHCDbLW7xq5BE0Bz5g                                         Shot Clock
# 14  1sQBPGypjSgEgJZvD8u8ty                                       Roll Some Mo
# 15  2qxmye6gAegTMjLKEBoR3d                                 Let Me Down Slowly
# 16  5ijp0ctfwwkmkR6hWDQnwn                                     Boom Shakalaka
# 17  4sW6L14RNFn7YxA4M2Pc64                                   I Need a Gangsta
# 18  6RUKPb4LETWmmr3iAEQktW                           Something Just Like This
# 19  0NS0ycRjNrnONGvqoou1ot                      Talkin' Bout (feat. Saweetie)
# 20  4356Typ82hUiFAynbLYbPn          DJ Got Us Fallin' In Love (feat. Pitbull)
# 21  4Z3qm2aWGTJuJKnv3EWwyD                                          Hide Away
# 22  60nZcImufyMA1MKQY3dcCH                     Happy - From "Despicable Me 2"
# 23  5PUawWFG1oIS2NwEcyHaCr                                        Uma Thurman
# 24  5N4erncE7kuUccm7zEmwzk                        Electricity (with Dua Lipa)
# 25  3bMNprrp2JDKZsGbiXpsJl                                       My Chick Bad
# 26  6JV2JOEocMgcZxYSZelKcc  CAN'T STOP THE FEELING! (from DreamWorks Anima...
# 27  39afswHs17v53znQm1gDTY                                         Take A Bow
# 28  2n4uOdMHzEvcZ0KP7iQnay                                     Lose My Breath
# 29  29LHe8kG3PraghUZOZYsw4                          Baby Boy (feat. Beyoncé )
# 30  2LEF1A8DOZ9wRYikWgVlZ8                                       Good Feeling
# 31  4AYX69oFP3UOS1CFmV9UfO                     Bottoms Up (feat. Nicki Minaj)
# 32  26rdOwwjC2UnweK3xeS58u              GDFR (feat. Sage the Gemini & Lookas)
# 33  27AHAtAirQapVldIm4c9ZX                                               Jump
# 34  05Sgj1Hx03ZXc57gsV1kfX                      It's Goin' Down (feat. Nitti)
# 35  3GZoWLVbmxcBys6g0DLFLf                   Supalonely (feat. Gus Dapperton)
# 36  5gqLY5H1ZyT3BScVr0nDMs                        Sway With Me (with GALXARA)
# 37  3OSCnSV4REXr8Y45woUfwj                     Feeling Blessed Never Stressed
# 38  2TpZlmChocrfeL5J6ed70t                                       Kingdom Come
# 39  36Rpz4MZQhGknLEmTmHr8v                       Supermodel (You Better Work)
# 40  3FAJ6O0NOHQV8Mc5Ri6ENp                             Heartbreak Anniversary
# 41  02VBYrHfVwfEWXk5DXyf0T                                Leave The Door Open
# 42  1gugDOSMREb34Xo0c1PlxM                               She Looks So Perfect
# 43  3Xv5C02Wxlek0dmrYAM5A8    Cha Cha Slide - Original Live Platinum Band Mix
# 44  4cluDES4hQEUhmXj6TXkSo                           What Makes You Beautiful
# 45  5nujrmhLynf4yMoMtj8AQF                          Levitating (feat. DaBaby)
# 46  4AIiCP2scA6jt6jAKfkvTX                              fue mejor (feat. SZA)
# 47  6TUSi9GZigMhBQ4k8zVK1Q                             Livin' for the Weekend
# 48  5GxUKIEkMXXZo1Tif0IzfC                                          Two Moons
# 49  7cPKQeCtGjRjoFVw6ub5rS                                          Good Time
# 50  6YQmDvj6XVAKSPLzjjLrFj                                      Ass Like That
# 51  72TFWvU3wUYdUuxejTTIzt                                               Work
# 52  1oHNvJVbFkexQc0BpQp7Y4                                          Starships
# 53  6epn3r7S14KUqlReYr77hA                                               Baby
# 54  7EQGXaVSyEDsCWKmUcfpLk                                          Die Young
# 55  7d1CFwrBmH34gmS0Hkbfbt                                             Replay
# 56  2Adn2LNgkHMH5TelQVAu4n                                   Pretty Girl Rock
# 57  3ZFTkvIE7kyPt6Nu3PEa7V                 Hips Don't Lie (feat. Wyclef Jean)
# 58  6cmm1LMvZdB5zsCwX5BjqE                                               Down
# 59  07Tx168RSsUS1HqkDIOZbH                                      Cupid Shuffle
#
#              first_artist                                        all_artists  \
# 0           Calvin Harris                        [Calvin Harris, Ayah Marar]
# 1       Stephanie Beatriz  [Stephanie Beatriz, Olga Merediz, Encanto - Cast]
# 2          Sara Bareilles                                   [Sara Bareilles]
# 3                   Nic D                                            [Nic D]
# 4             Los Del Rio                                      [Los Del Rio]
# 5                  Eminem                                           [Eminem]
# 6          Arctic Monkeys                                   [Arctic Monkeys]
# 7                   B.o.B                           [B.o.B, Priscilla Renea]
# 8              Bea Miller                                       [Bea Miller]
# 9                 DJ Ötzi                                          [DJ Ötzi]
# 10           Otis Redding                                     [Otis Redding]
# 11           Isaac Carree                      [Isaac Carree, James Fortune]
# 12          Queen Latifah                                    [Queen Latifah]
# 13               Ella Mai                                         [Ella Mai]
# 14             Lucky Daye                                       [Lucky Daye]
# 15          Alec Benjamin                                    [Alec Benjamin]
# 16                  Moksi                        [Moksi, Digitzz, Emy Perez]
# 17             Dj Preetia                                       [Dj Preetia]
# 18       The Chainsmokers                       [The Chainsmokers, Coldplay]
# 19                   Loui                                   [Loui, Saweetie]
# 20                  Usher                                   [Usher, Pitbull]
# 21                   Daya                                             [Daya]
# 22      Pharrell Williams                                [Pharrell Williams]
# 23           Fall Out Boy                                     [Fall Out Boy]
# 24              Silk City          [Silk City, Dua Lipa, Diplo, Mark Ronson]
# 25               Ludacris                            [Ludacris, Nicki Minaj]
# 26      Justin Timberlake                                [Justin Timberlake]
# 27                Rihanna                                          [Rihanna]
# 28        Destiny's Child                                  [Destiny's Child]
# 29              Sean Paul                               [Sean Paul, Beyoncé]
# 30               Flo Rida                                         [Flo Rida]
# 31             Trey Songz                          [Trey Songz, Nicki Minaj]
# 32               Flo Rida                [Flo Rida, Sage The Gemini, Lookas]
# 33             Kris Kross                                       [Kris Kross]
# 34               Yung Joc                                  [Yung Joc, Nitti]
# 35                  BENEE                             [BENEE, Gus Dapperton]
# 36               Saweetie                                [Saweetie, GALXARA]
# 37             Yung Nazty                                       [Yung Nazty]
# 38            Jon Bellion                                      [Jon Bellion]
# 39                 RuPaul                                           [RuPaul]
# 40                 Giveon                                           [Giveon]
# 41             Bruno Mars           [Bruno Mars, Anderson .Paak, Silk Sonic]
# 42    5 Seconds of Summer                              [5 Seconds of Summer]
# 43              DJ Casper                                        [DJ Casper]
# 44          One Direction                                    [One Direction]
# 45               Dua Lipa                                 [Dua Lipa, DaBaby]
# 46             Kali Uchis                                  [Kali Uchis, SZA]
# 47  Fitz and The Tantrums                            [Fitz and The Tantrums]
# 48             BoyWithUke                                       [BoyWithUke]
# 49    Ocean Park Standoff                              [Ocean Park Standoff]
# 50         Victoria Monét                                   [Victoria Monét]
# 51                Rihanna                                   [Rihanna, Drake]
# 52            Nicki Minaj                                      [Nicki Minaj]
# 53          Justin Bieber                          [Justin Bieber, Ludacris]
# 54                  Kesha                                            [Kesha]
# 55                Zendaya                                          [Zendaya]
# 56            Keri Hilson                                      [Keri Hilson]
# 57                Shakira                             [Shakira, Wyclef Jean]
# 58               Jay Sean                              [Jay Sean, Lil Wayne]
# 59                  Cupid                                            [Cupid]
#
#     danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0          0.725   0.874    0    -3.715     0      0.002620          0.000412
# 1          0.594   0.628    1    -6.345     1      0.120000          0.000000
# 2          0.583   0.786    2    -3.142     0      0.020800          0.000000
# 3          0.925   0.558    2    -5.362     1      0.178000          0.000000
# 4          0.923   0.679    8   -14.019     1      0.428000          0.000131
# 5          0.763   0.827    7    -3.927     1      0.023200          0.000000
# 6          0.464   0.417    0    -9.345     0      0.136000          0.022000
# 7          0.722   0.697   10    -7.083     1      0.239000          0.000000
# 8          0.740   0.415    0    -8.914     1      0.242000          0.000156
# 9          0.666   0.968   10    -3.196     1      0.123000          0.000000
# 10         0.414   0.342    5    -9.676     0      0.531000          0.000013
# 11         0.620   0.681    2    -5.540     1      0.135000          0.000000
# 12         0.286   0.493    7    -7.335     1      0.629000          0.000000
# 13         0.512   0.512    4    -6.008     0      0.654000          0.000000
# 14         0.389   0.507   11    -9.026     1      0.259000          0.044100
# 15         0.652   0.557    1    -5.714     0      0.740000          0.000000
# 16         0.870   0.787    4    -8.091     0      0.026700          0.144000
# 17         0.496   0.518   10    -6.791     0      0.469000          0.000000
# 18         0.617   0.635   11    -6.769     0      0.049800          0.000014
# 19         0.885   0.466    1    -6.128     1      0.039600          0.000000
# 20         0.663   0.861    7    -3.398     0      0.033800          0.000000
# 21         0.886   0.818   11    -3.649     0      0.218000          0.000003
# 22         0.647   0.822    5    -4.662     0      0.219000          0.000000
# 23         0.623   0.962    4    -2.616     0      0.103000          0.000174
# 24         0.588   0.670    0    -6.439     1      0.010400          0.000003
# 25         0.624   0.723    1    -6.782     1      0.172000          0.000000
# 26         0.666   0.830    0    -5.715     1      0.012300          0.000000
# 27         0.708   0.470    9    -7.590     1      0.248000          0.000000
# 28         0.814   0.899    1    -5.958     1      0.007270          0.219000
# 29         0.658   0.621    1    -5.725     1      0.066700          0.000002
# 30         0.706   0.890    1    -4.444     0      0.058800          0.002860
# 31         0.844   0.601    1    -5.283     1      0.020500          0.000000
# 32         0.657   0.827    5    -4.036     1      0.000704          0.005340
# 33         0.749   0.745    2   -10.625     1      0.000501          0.004030
# 34         0.888   0.577    1    -7.702     0      0.098600          0.000000
# 35         0.862   0.631    7    -4.746     1      0.291000          0.000209
# 36         0.621   0.849    3    -4.243     0      0.004680          0.000005
# 37         0.702   0.536    0    -7.622     1      0.108000          0.000000
# 38         0.911   0.587    0    -5.351     1      0.088200          0.000002
# 39         0.792   0.562    7   -11.379     1      0.015200          0.000075
# 40         0.449   0.465    0    -8.964     1      0.524000          0.000001
# 41         0.586   0.616    5    -7.964     1      0.182000          0.000000
# 42         0.494   0.951    9    -4.237     1      0.000569          0.000000
# 43         0.978   0.695    6    -5.746     1      0.001260          0.000050
# 44         0.726   0.787    4    -2.494     1      0.009000          0.000000
# 45         0.702   0.825    6    -3.787     0      0.008830          0.000000
# 46         0.769   0.384    5    -7.414     0      0.239000          0.000227
# 47         0.720   0.881   11    -3.793     0      0.025900          0.000000
# 48         0.841   0.502    6    -9.068     0      0.520000          0.000187
# 49         0.708   0.620    8    -5.903     1      0.010600          0.000006
# 50         0.660   0.715    4    -7.326     0      0.093400          0.000526
# 51         0.725   0.534   11    -6.238     1      0.075200          0.000000
# 52         0.747   0.716   11    -2.457     0      0.135000          0.000000
# 53         0.728   0.859    5    -5.237     0      0.040100          0.000000
# 54         0.711   0.700    1    -4.805     0      0.004980          0.000125
# 55         0.688   0.723    6    -6.682     0      0.041600          0.000200
# 56         0.666   0.870   11    -5.004     0      0.203000          0.000000
# 57         0.778   0.824   10    -5.892     0      0.284000          0.000000
# 58         0.727   0.680    2    -4.498     1      0.010100          0.000000
# 59         0.785   0.582    5    -4.877     0      0.191000          0.000000
#
#     liveness  valence    tempo  duration_ms  time_signature
# 0     0.0958    0.748  127.985       247933               4
# 1     0.0582    0.556  141.391       257213               4
# 2     0.1880    0.573  123.055       258827               4
# 3     0.1250    0.467  119.992       153297               4
# 4     0.0908    0.965  103.017       251293               4
# 5     0.2660    0.710  135.986       261603               4
# 6     0.0974    0.479   67.528       183956               4
# 7     0.0620    0.487  120.132       212006               4
# 8     0.3190    0.156  136.029       180161               4
# 9     0.3470    0.834  135.099       219240               4
# 10    0.2750    0.239  167.166       254960               3
# 11    0.1130    0.644  139.566       263827               4
# 12    0.1640    0.241  173.556       253227               4
# 13    0.1480    0.434   95.110       201609               1
# 14    0.1420    0.364   74.718       292885               4
# 15    0.1240    0.483  150.073       169354               4
# 16    0.2290    0.551  123.953       178321               4
# 17    0.3930    0.121  121.981       169153               4
# 18    0.1640    0.446  103.019       247160               4
# 19    0.1270    0.272   75.014       126225               4
# 20    0.0820    0.654  119.963       220800               4
# 21    0.0687    0.469   95.050       192387               4
# 22    0.0908    0.962  160.019       232720               4
# 23    0.2640    0.676  149.963       211573               4
# 24    0.3380    0.505  118.159       238173               4
# 25    0.4830    0.757   84.789       216933               4
# 26    0.1910    0.702  113.030       236002               4
# 27    0.0852    0.536   82.007       229413               4
# 28    0.0979    0.545  119.011       242013               4
# 29    0.1420    0.817   91.267       246707               4
# 30    0.3060    0.684  128.011       248133               4
# 31    0.3850    0.331   73.989       242013               4
# 32    0.0650    0.690  145.889       190186               4
# 33    0.3330    0.481  101.972       195107               4
# 34    0.1310    0.609   84.003       241840               4
# 35    0.1230    0.841  128.978       223488               4
# 36    0.3280    0.875  130.979       168018               4
# 37    0.2050    0.621  112.041       156761               4
# 38    0.1490    0.743   96.959       139867               4
# 39    0.4280    0.592  126.221       239933               4
# 40    0.3030    0.543   89.087       198371               3
# 41    0.0927    0.719  148.088       242096               4
# 42    0.3270    0.441  160.025       202496               4
# 43    0.2840    0.496  122.027       387493               4
# 44    0.0596    0.888  124.990       199987               4
# 45    0.0674    0.915  102.977       203064               4
# 46    0.0762    0.230  106.002       230965               4
# 47    0.1030    0.839  150.136       175719               4
# 48    0.1030    0.863  109.965       224747               4
# 49    0.3540    0.912  145.073       172944               4
# 50    0.1720    0.620   80.058       220208               4
# 51    0.0919    0.558   91.974       219320               4
# 52    0.2510    0.751  125.008       210627               4
# 53    0.1110    0.535   65.043       214240               4
# 54    0.2150    0.801  128.001       211920               4
# 55    0.3020    0.618  140.023       209187               4
# 56    0.0851    0.900  160.014       243920               4
# 57    0.4050    0.758  100.024       218093               4
# 58    0.0821    0.728  132.012       212507               4
# 59    0.2000    0.861   71.774       231360               4

# %%
df_spotR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60 entries, 0 to 59
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                60 non-null     object
#  1   title             60 non-null     object
#  2   first_artist      60 non-null     object
#  3   all_artists       60 non-null     object
#  4   danceability      60 non-null     float64
#  5   energy            60 non-null     float64
#  6   key               60 non-null     int64
#  7   loudness          60 non-null     float64
#  8   mode              60 non-null     int64
#  9   acousticness      60 non-null     float64
#  10  instrumentalness  60 non-null     float64
#  11  liveness          60 non-null     float64
#  12  valence           60 non-null     float64
#  13  tempo             60 non-null     float64
#  14  duration_ms       60 non-null     int64
#  15  time_signature    60 non-null     int64
# dtypes: float64(8), int64(4), object(4)
# memory usage: 8.0+ KB

# %%
df_spotR.describe()
# Out:
#        danceability     energy        key   loudness       mode  acousticness  \
# count     60.000000  60.000000  60.000000  60.000000  60.000000     60.000000
# mean       0.694050   0.679283   4.800000  -6.107950   0.533333      0.157032
# std        0.140175   0.159211   3.767839   2.285923   0.503098      0.184786
# min        0.286000   0.342000   0.000000 -14.019000   0.000000      0.000501
# 25%        0.622500   0.557750   1.000000  -7.354750   0.000000      0.019175
# 50%        0.707000   0.680500   5.000000  -5.819000   1.000000      0.096000
# 75%        0.771250   0.824250   7.250000  -4.484500   1.000000      0.224000
# max        0.978000   0.968000  11.000000  -2.457000   1.000000      0.740000
#
#        instrumentalness   liveness    valence       tempo    duration_ms  \
# count         60.000000  60.000000  60.000000   60.000000      60.000000
# mean           0.007398   0.191813   0.613933  117.482850  218726.350000
# std            0.033923   0.113870   0.208044   27.048127   40139.568963
# min            0.000000   0.058200   0.121000   65.043000  126225.000000
# 25%            0.000000   0.095025   0.482500   96.496750  197555.000000
# 50%            0.000000   0.148500   0.619000  121.056500  219280.000000
# 75%            0.000137   0.288500   0.757250  135.996750  242033.750000
# max            0.219000   0.483000   0.965000  173.556000  387493.000000
#
#        time_signature
# count       60.000000
# mean         3.916667
# std          0.423531
# min          1.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000

# %%
df_spotR.corr().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_0269b_row0_col0, #T_0269b_row1_col1, #T_0269b_row2_col2, #T_0269b_row3_col3, #T_0269b_row4_col4, #T_0269b_row5_col5, #T_0269b_row6_col6, #T_0269b_row7_col7, #T_0269b_row8_col8, #T_0269b_row9_col9, #T_0269b_row10_col10, #T_0269b_row11_col11 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0269b_row0_col1, #T_0269b_row9_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_0269b_row0_col2, #T_0269b_row2_col7 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_0269b_row0_col3, #T_0269b_row7_col11, #T_0269b_row9_col8 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_0269b_row0_col4 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_0269b_row0_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_0269b_row0_col6, #T_0269b_row2_col0 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_0269b_row0_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_0269b_row0_col8 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_0269b_row0_col9, #T_0269b_row1_col5, #T_0269b_row3_col4, #T_0269b_row3_col10, #T_0269b_row4_col2, #T_0269b_row5_col0, #T_0269b_row5_col1, #T_0269b_row5_col3, #T_0269b_row5_col6, #T_0269b_row5_col8, #T_0269b_row5_col11, #T_0269b_row8_col7 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0269b_row0_col10 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_0269b_row0_col11 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_0269b_row1_col0, #T_0269b_row11_col8 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_0269b_row1_col2, #T_0269b_row1_col6 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_0269b_row1_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_0269b_row1_col4 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0269b_row1_col7, #T_0269b_row9_col7 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_0269b_row1_col8 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_0269b_row1_col9 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_0269b_row1_col10, #T_0269b_row4_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_0269b_row1_col11 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_0269b_row2_col1 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_0269b_row2_col3 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0269b_row2_col4, #T_0269b_row5_col4 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_0269b_row2_col5 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_0269b_row2_col6, #T_0269b_row11_col5 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_0269b_row2_col8 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_0269b_row2_col9, #T_0269b_row10_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_0269b_row2_col10 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_0269b_row2_col11 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_0269b_row3_col0, #T_0269b_row8_col9 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_0269b_row3_col1 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_0269b_row3_col2, #T_0269b_row7_col3, #T_0269b_row9_col4 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_0269b_row3_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_0269b_row3_col6, #T_0269b_row6_col2 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_0269b_row3_col7 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0269b_row3_col8, #T_0269b_row8_col11 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_0269b_row3_col9 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_0269b_row3_col11, #T_0269b_row9_col5, #T_0269b_row10_col1 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_0269b_row4_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_0269b_row4_col1, #T_0269b_row5_col2, #T_0269b_row7_col9, #T_0269b_row10_col8 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_0269b_row4_col3, #T_0269b_row8_col4 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_0269b_row4_col5, #T_0269b_row7_col4, #T_0269b_row10_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_0269b_row4_col7, #T_0269b_row10_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_0269b_row4_col8, #T_0269b_row11_col6 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_0269b_row4_col9 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_0269b_row4_col10, #T_0269b_row8_col5 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_0269b_row4_col11 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_0269b_row5_col7, #T_0269b_row7_col10, #T_0269b_row9_col0 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_0269b_row5_col9 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_0269b_row5_col10, #T_0269b_row7_col6 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_0269b_row6_col0 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_0269b_row6_col1 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_0269b_row6_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_0269b_row6_col4, #T_0269b_row10_col3 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_0269b_row6_col5, #T_0269b_row10_col9, #T_0269b_row11_col9 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_0269b_row6_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_0269b_row6_col8 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_0269b_row6_col9, #T_0269b_row7_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_0269b_row6_col10, #T_0269b_row8_col10 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_0269b_row6_col11 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_0269b_row7_col1 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_0269b_row7_col2 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_0269b_row7_col5 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_0269b_row7_col8, #T_0269b_row11_col7, #T_0269b_row11_col10 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_0269b_row8_col0 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_0269b_row8_col1 {
#   background-color: #3282be;
#   color: #f1f1f1;
# }
# #T_0269b_row8_col2 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_0269b_row8_col3 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_0269b_row8_col6 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_0269b_row9_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_0269b_row9_col2, #T_0269b_row10_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_0269b_row9_col6 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_0269b_row9_col10 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_0269b_row9_col11 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_0269b_row10_col6 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_0269b_row10_col7 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_0269b_row10_col11 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_0269b_row11_col0 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_0269b_row11_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_0269b_row11_col2 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_0269b_row11_col3 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_0269b_row11_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# </style>
# <table id="T_0269b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >danceability</th>
#       <th class="col_heading level0 col1" >energy</th>
#       <th class="col_heading level0 col2" >key</th>
#       <th class="col_heading level0 col3" >loudness</th>
#       <th class="col_heading level0 col4" >mode</th>
#       <th class="col_heading level0 col5" >acousticness</th>
#       <th class="col_heading level0 col6" >instrumentalness</th>
#       <th class="col_heading level0 col7" >liveness</th>
#       <th class="col_heading level0 col8" >valence</th>
#       <th class="col_heading level0 col9" >tempo</th>
#       <th class="col_heading level0 col10" >duration_ms</th>
#       <th class="col_heading level0 col11" >time_signature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0269b_level0_row0" class="row_heading level0 row0" >

# %%
df_concatP=pd.concat([df_userP, df_spotR])
df_concatP.shape
# Out:
# (120, 16)

# %%
df_concatP.drop_duplicates(subset="title", keep=False, inplace=True)

# %%
df_concatP.shape
# Out:
# (112, 16)

# %%
display(df_concatP)
# Out:
#                         id                               title  \
# 0   1DunhgeZSEgWiIYbHqXl0c                               Latch
# 1   52xJxFP6TqMuO4Yt0eOkMz           We Don't Talk About Bruno
# 2   7oOOI85fVQvVnK5ynNMdW7      Rock with You - Single Version
# 3   7ruiupyTfOflj8JSHCG6vL                             Go Gina
# 4   0rFOs9paloAvEtzwDX1Kmc                              Bubbly
# ..                     ...                                 ...
# 54  7EQGXaVSyEDsCWKmUcfpLk                           Die Young
# 55  7d1CFwrBmH34gmS0Hkbfbt                              Replay
# 56  2Adn2LNgkHMH5TelQVAu4n                    Pretty Girl Rock
# 57  3ZFTkvIE7kyPt6Nu3PEa7V  Hips Don't Lie (feat. Wyclef Jean)
# 58  6cmm1LMvZdB5zsCwX5BjqE                                Down
#
#                   first_artist  \
# 0                   Disclosure
# 1   Carolina Gaitán - La Gaita
# 2              Michael Jackson
# 3                          SZA
# 4               Colbie Caillat
# ..                         ...
# 54                       Kesha
# 55                     Zendaya
# 56                 Keri Hilson
# 57                     Shakira
# 58                    Jay Sean
#
#                                           all_artists  danceability  energy  \
# 0                             [Disclosure, Sam Smith]         0.729   0.735
# 1   [Carolina Gaitán - La Gaita, Mauro Castillo, A...         0.577   0.450
# 2                                   [Michael Jackson]         0.808   0.535
# 3                                               [SZA]         0.569   0.610
# 4                                    [Colbie Caillat]         0.697   0.474
# ..                                                ...           ...     ...
# 54                                            [Kesha]         0.711   0.700
# 55                                          [Zendaya]         0.688   0.723
# 56                                      [Keri Hilson]         0.666   0.870
# 57                             [Shakira, Wyclef Jean]         0.778   0.824
# 58                              [Jay Sean, Lil Wayne]         0.727   0.680
#
#     key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0     1    -5.455     1       0.01780          0.000193    0.0890    0.544
# 1     0    -8.516     0       0.35700          0.000000    0.1110    0.830
# 2     1   -12.521     1       0.17900          0.000099    0.1580    0.848
# 3     6    -6.105     0       0.78400          0.000000    0.3920    0.413
# 4     9    -6.663     1       0.60300          0.000000    0.1100    0.249
# ..  ...       ...   ...           ...               ...       ...      ...
# 54    1    -4.805     0       0.00498          0.000125    0.2150    0.801
# 55    6    -6.682     0       0.04160          0.000200    0.3020    0.618
# 56   11    -5.004     0       0.20300          0.000000    0.0851    0.900
# 57   10    -5.892     0       0.28400          0.000000    0.4050    0.758
# 58    2    -4.498     1       0.01010          0.000000    0.0821    0.728
#
#       tempo  duration_ms  time_signature
# 0   121.986       255867               4
# 1   205.863       216120               4
# 2   114.031       220627               4
# 3    79.680       161613               4
# 4   127.904       196280               4
# ..      ...          ...             ...
# 54  128.001       211920               4
# 55  140.023       209187               4
# 56  160.014       243920               4
# 57  100.024       218093               4
# 58  132.012       212507               4
#
# [112 rows x 16 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.pairplot(df_userP)

# %%
sns.pairplot(df_spotR)

# %%
df_userP.drop(["id", "title", "first_artist", "all_artists"], axis = 1, inplace = True)
df_spotR.drop(["id", "title", "first_artist", "all_artists"], axis = 1, inplace = True)
df_concatP.drop(["id", "title", "first_artist", "all_artists"], axis = 1, inplace = True)
display(df_concatP)
# Out:
#     danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0          0.729   0.735    1    -5.455     1       0.01780          0.000193
# 1          0.577   0.450    0    -8.516     0       0.35700          0.000000
# 2          0.808   0.535    1   -12.521     1       0.17900          0.000099
# 3          0.569   0.610    6    -6.105     0       0.78400          0.000000
# 4          0.697   0.474    9    -6.663     1       0.60300          0.000000
# ..           ...     ...  ...       ...   ...           ...               ...
# 54         0.711   0.700    1    -4.805     0       0.00498          0.000125
# 55         0.688   0.723    6    -6.682     0       0.04160          0.000200
# 56         0.666   0.870   11    -5.004     0       0.20300          0.000000
# 57         0.778   0.824   10    -5.892     0       0.28400          0.000000
# 58         0.727   0.680    2    -4.498     1       0.01010          0.000000
#
#     liveness  valence    tempo  duration_ms  time_signature
# 0     0.0890    0.544  121.986       255867               4
# 1     0.1110    0.830  205.863       216120               4
# 2     0.1580    0.848  114.031       220627               4
# 3     0.3920    0.413   79.680       161613               4
# 4     0.1100    0.249  127.904       196280               4
# ..       ...      ...      ...          ...             ...
# 54    0.2150    0.801  128.001       211920               4
# 55    0.3020    0.618  140.023       209187               4
# 56    0.0851    0.900  160.014       243920               4
# 57    0.4050    0.758  100.024       218093               4
# 58    0.0821    0.728  132.012       212507               4
#
# [112 rows x 12 columns]

# %%
#df_userP = df_userP.astype(float)
#df_spotR = df_spotR.astype(float)

# %%
from sklearn.model_selection import train_test_split
x_user_dance, y_user_dance = df_userP.drop('danceability',axis=1),df_userP['danceability']
x_train_user_dance,x_test_user_dance,y_train_user_dance,y_test_user_dance = train_test_split(x_user_dance, y_user_dance, test_size=0.3, random_state=1)
x_train_user_dance.shape ,x_test_user_dance.shape ,y_train_user_dance.shape ,y_test_user_dance.shape
# Out:
# ((42, 11), (18, 11), (42,), (18,))

# %%
x_rec_dance, y_rec_dance = df_spotR.drop('danceability',axis=1),df_spotR['danceability']
x_train_rec_dance,x_test_rec_dance,y_train_rec_dance,y_test_rec_dance = train_test_split(x_rec_dance, y_rec_dance, test_size=0.3, random_state=1)
x_train_rec_dance.shape ,x_test_rec_dance.shape ,y_train_rec_dance.shape ,y_test_rec_dance.shape
# Out:
# ((42, 11), (18, 11), (42,), (18,))

# %%
x_concat_dance, y_concat_dance = df_concatP,df_concatP['danceability']
x_train_concat_dance,x_test_concat_dance,y_train_concat_dance,y_test_concat_dance = train_test_split(x_concat_dance, y_concat_dance, test_size=0.3, random_state=1)
x_train_concat_dance.shape ,x_test_concat_dance.shape ,y_train_concat_dance.shape ,y_test_concat_dance.shape
# Out:
# ((78, 12), (34, 12), (78,), (34,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train_user_dance)
x_train_user_dance=scaler.transform(x_train_user_dance)
x_test_rec_dance=scaler.transform(x_test_rec_dance)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train_concat_dance)
x_train_concat_dance=scaler.transform(x_train_concat_dance)
x_test_concat_dance=scaler.transform(x_test_concat_dance)

# %%
from sklearn.ensemble import AdaBoostRegressor
adaR = AdaBoostRegressor(random_state=0, n_estimators=100)
adaR.fit(x_train_user_dance, y_train_user_dance)
adaR.score(x_train_user_dance, y_train_user_dance)
# Out:
# 0.9166687118408838

# %%
adaR.score(x_train_rec_dance.values, y_train_rec_dance.values)
# Out:
# -0.7114393901868259

# %%
from sklearn.ensemble import RandomForestRegressor
modelRF = RandomForestRegressor(random_state=0).fit(x_train_user_dance, y_train_user_dance)
modelRF.score(x_train_user_dance, y_train_user_dance)
#r2_score(x_test_rec_dance, y_test_user_dance)
# Out:
# 0.9128967340002775

# %%
modelRF.score(x_test_rec_dance, y_test_rec_dance)
# Out:
# 0.2835213693828915

# %%
from sklearn.linear_model import LinearRegression
modelLR = LinearRegression().fit(x_train_user_dance, y_train_user_dance)
modelLR.score(x_train_user_dance, y_train_user_dance)
# Out:
# 0.6667464758669479

# %%
modelLR.score(x_train_rec_dance.values, y_train_rec_dance.values)
# Out:
# -2423873295.340097

# %%
from sklearn.ensemble import BaggingRegressor
modelBR = BaggingRegressor(adaR, n_estimators=100, max_samples=1.0, bootstrap=True, bootstrap_features=True,
                            max_features=1.0, random_state=42, n_jobs=-1).fit(x_train_user_dance, y_train_user_dance)
modelBR.score(x_train_user_dance, y_train_user_dance)
# Out:
# 0.8452936175809943

# %%
modelBR.score(x_train_rec_dance.values, y_train_rec_dance.values)
# Out:
# -0.6304269955051445

# %%
from sklearn.ensemble import StackingRegressor
estimators = [('adaR', AdaBoostRegressor(random_state=0, n_estimators=100)),(('BR'), modelBR)]
modelSR = StackingRegressor(estimators=estimators, final_estimator=RandomForestRegressor(random_state=0)).fit(x_train_user_dance, y_train_user_dance)
modelSR.score(x_train_user_dance, y_train_user_dance)
# Out:
# 0.5447956242472265

# %%
modelSR.score(x_train_rec_dance.values, y_train_rec_dance.values)
# Out:
# -0.48583964857407613

# %%
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
import json
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import StackingRegressor


df_user_playlist = pd.read_json('user_json.json')
df_user_playlist.drop(["id", "title", "first_artist", "all_artists"], axis=1, inplace=True)

df_spot_rec = pd.read_json('rec_json.json')
df_spot_rec.drop(["id", "title", "first_artist", "all_artists"], axis=1, inplace=True)


def calculate_feature_scores(feature_name: str) -> None:

    x_user, y_user = df_user_playlist.drop(feature_name, axis=1), df_user_playlist[feature_name]
    x_train_user, x_test_user, y_train_user, y_test_user = train_test_split(x_user, y_user, test_size=0.3, random_state=1)
    print(f"User shapes: {x_train_user.shape} {x_test_user.shape} {y_train_user.shape} {y_test_user.shape}")

    x_rec, y_rec = df_spot_rec.drop(feature_name, axis=1), df_spot_rec[feature_name]
    x_train_rec, x_test_rec, y_train_rec, y_test_rec = train_test_split(x_rec, y_rec, test_size=0.3, random_state=1)
    print(f"Recommendation shapes: {x_train_rec.shape} {x_test_rec.shape} {y_train_rec.shape} {y_test_rec.shape}")

    scaler = StandardScaler()
    x_train_user = scaler.fit_transform(x_train_user)
    #y_train_user = scaler.fit_transform(y_train_user.values.reshape(-1, 1))
    x_train_rec = scaler.fit_transform(x_train_rec)
    #y_train_rec = scaler.fit_transform(y_train_rec.values.reshape(-1, 1))

    print("---> AdaBoostRegressor")
    adaR = AdaBoostRegressor(random_state=0, n_estimators=100).fit(x_train_user, y_train_user)
    print(f"User score: {adaR.score(x_train_user, y_train_user):.3f}")
    print(f"Recommendation score: {adaR.score(x_train_rec, y_train_rec):.3f}")

    print("---> RandomForestRegressor")
    modelRF = RandomForestRegressor(random_state=0).fit(x_train_user, y_train_user)
    print(f"User score: {modelRF.score(x_train_user, y_train_user):.3f}")
    print(f"Recommendation score: {modelRF.score(x_train_rec, y_train_rec):.3f}")

    print("---> LinearRegression")
    modelLR = LinearRegression().fit(x_train_user, y_train_user)
    print(f"User score: {modelLR.score(x_train_user, y_train_user):.3f}")
    print(f"Recommendation score: {modelLR.score(x_train_rec, y_train_rec):.3f}")

    print("---> BaggingRegressor")
    modelBR = BaggingRegressor(adaR, n_estimators=100, max_samples=1.0, bootstrap=True, bootstrap_features=True,
                               max_features=1.0, random_state=42, n_jobs=-1).fit(x_train_user, y_train_user)
    print(f"User score: {modelBR.score(x_train_user, y_train_user):.3f}")
    print(f"Recommendation score: {modelBR.score(x_train_rec, y_train_rec):.3f}")

    print("---> StackingRegressor: AdaBoostRegressor & BaggingRegressor")
    modelSR = StackingRegressor(
        estimators=[('AdaBoostRegressor', AdaBoostRegressor(random_state=0, n_estimators=100)), (('BaggingRegressor'), modelBR)],
        final_estimator=RandomForestRegressor(random_state=0)
    ).fit(x_train_user, y_train_user)
    print(f"User score: {modelSR.score(x_train_user, y_train_user):.3f}")
    print(f"Recommendation score: {modelSR.score(x_train_rec, y_train_rec):.3f}")


feature_list = df_user_playlist.columns.values.tolist()
for index, feature_name in enumerate(feature_list, start=1):
    print(f"\n{index} / {len(feature_list)} Feature: {feature_name}")
    calculate_feature_scores(feature_name)
# Out:
# 1 / 12 Feature: danceability
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.917
# Recommendation score: 0.217
# ---> RandomForestRegressor
# User score: 0.913
# Recommendation score: 0.185
# ---> LinearRegression
# User score: 0.667
# Recommendation score: -0.171
# ---> BaggingRegressor
# User score: 0.845
# Recommendation score: 0.242
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.545
# Recommendation score: 0.376
#
# 2 / 12 Feature: energy
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.953
# Recommendation score: 0.457
# ---> RandomForestRegressor
# User score: 0.938
# Recommendation score: 0.390
# ---> LinearRegression
# User score: 0.698
# Recommendation score: 0.393
# ---> BaggingRegressor
# User score: 0.881
# Recommendation score: 0.473
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.717
# Recommendation score: 0.324
#
# 3 / 12 Feature: key
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.945
# Recommendation score: -0.063
# ---> RandomForestRegressor
# User score: 0.858
# Recommendation score: -0.084
# ---> LinearRegression
# User score: 0.243
# Recommendation score: -0.044
# ---> BaggingRegressor
# User score: 0.780
# Recommendation score: -0.036
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.102
# Recommendation score: -0.200
#
# 4 / 12 Feature: loudness
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.945
# Recommendation score: 0.299
# ---> RandomForestRegressor
# User score: 0.921
# Recommendation score: 0.275
# ---> LinearRegression
# User score: 0.644
# Recommendation score: 0.348
# ---> BaggingRegressor
# User score: 0.858
# Recommendation score: 0.260
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.588
# Recommendation score: 0.168
#
# 5 / 12 Feature: mode
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.995
# Recommendation score: -0.458
# ---> RandomForestRegressor
# User score: 0.843
# Recommendation score: -0.142
# ---> LinearRegression
# User score: 0.202
# Recommendation score: -0.228
# ---> BaggingRegressor
# User score: 0.819
# Recommendation score: -0.124
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: -1.047
# Recommendation score: -0.487
#
# 6 / 12 Feature: acousticness
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.964
# Recommendation score: -0.699
# ---> RandomForestRegressor
# User score: 0.956
# Recommendation score: -0.387
# ---> LinearRegression
# User score: 0.716
# Recommendation score: 0.287
# ---> BaggingRegressor
# User score: 0.923
# Recommendation score: 0.139
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.885
# Recommendation score: -0.702
#
# 7 / 12 Feature: instrumentalness
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.999
# Recommendation score: -0.675
# ---> RandomForestRegressor
# User score: 0.859
# Recommendation score: -3.862
# ---> LinearRegression
# User score: 0.268
# Recommendation score: -3.012
# ---> BaggingRegressor
# User score: 0.842
# Recommendation score: -0.939
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: -0.731
# Recommendation score: -2.036
#
# 8 / 12 Feature: liveness
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.935
# Recommendation score: -0.611
# ---> RandomForestRegressor
# User score: 0.833
# Recommendation score: -0.689
# ---> LinearRegression
# User score: 0.263
# Recommendation score: -0.878
# ---> BaggingRegressor
# User score: 0.830
# Recommendation score: -0.443
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: -0.520
# Recommendation score: -0.935
#
# 9 / 12 Feature: valence
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.902
# Recommendation score: -0.153
# ---> RandomForestRegressor
# User score: 0.878
# Recommendation score: -0.118
# ---> LinearRegression
# User score: 0.480
# Recommendation score: -0.233
# ---> BaggingRegressor
# User score: 0.779
# Recommendation score: 0.048
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.353
# Recommendation score: -0.263
#
# 10 / 12 Feature: tempo
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.913
# Recommendation score: -0.306
# ---> RandomForestRegressor
# User score: 0.850
# Recommendation score: -0.090
# ---> LinearRegression
# User score: 0.416
# Recommendation score: -0.504
# ---> BaggingRegressor
# User score: 0.774
# Recommendation score: -0.080
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: -0.808
# Recommendation score: -0.434
#
# 11 / 12 Feature: duration_ms
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 0.840
# Recommendation score: -0.096
# ---> RandomForestRegressor
# User score: 0.798
# Recommendation score: -0.075
# ---> LinearRegression
# User score: 0.230
# Recommendation score: -0.402
# ---> BaggingRegressor
# User score: 0.722
# Recommendation score: -0.052
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: -1.143
# Recommendation score: -0.043
#
# 12 / 12 Feature: time_signature
# User shapes: (42, 11) (18, 11) (42,) (18,)
# Recommendation shapes: (42, 11) (18, 11) (42,) (18,)
# ---> AdaBoostRegressor
# User score: 1.000
# Recommendation score: -0.252
# ---> RandomForestRegressor
# User score: 0.876
# Recommendation score: -0.557
# ---> LinearRegression
# User score: 0.580
# Recommendation score: -0.641
# ---> BaggingRegressor
# User score: 0.860
# Recommendation score: -0.075
# ---> StackingRegressor: AdaBoostRegressor & BaggingRegressor
# User score: 0.176
# Recommendation score: 0.144
