# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json

# %%
auth_manager = SpotifyClientCredentials(client_id ='5ac39870b4b941b8b423b7edc976d9d5',
                                       client_secret = '6af8fdb8f5da42b49685d4d840d8ef15')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#test of just artist
playlist_index=0

sp = spotipy.Spotify(auth_manager=auth_manager)
playlist_link = 'https://open.spotify.com/playlist/7gpp9QfGBaAKM2Tfn3rfZT?si=6673774fcd7c4e34&nd=1'
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
results = sp.user_playlist('missblah',playlist_URI,'tracks')

# %%
playlist_tracks_data = results['tracks']
playlist_tracks_id = []
playlist_tracks_titles = []
playlist_tracks_artists = []
playlist_tracks_first_artists = []

for track in playlist_tracks_data['items']:
    playlist_tracks_id.append(track['track']['id'])
    playlist_tracks_titles.append(track['track']['name'])
    # adds a list of all artists involved in the song to the list of artists for the playlist
    artist_list = []
    for artist in track['track']['artists']:
        artist_list.append(artist['name'])
    playlist_tracks_artists.append(artist_list)
    playlist_tracks_first_artists.append(artist_list[0])

# %%
features = sp.audio_features(playlist_tracks_id)

# %%
import numpy as np
import pandas as pd
rec_features_df = pd.DataFrame(data=features, columns=features[0].keys())

# %%
rec_features_df['title'] = playlist_tracks_titles
rec_features_df['first_artist'] = playlist_tracks_first_artists
rec_features_df['all_artists'] = playlist_tracks_artists
#rec_features_df = rec_features_df.set_index('id')
rec_features_df = rec_features_df[['id', 'title', 'first_artist', 'all_artists',
                           'danceability', 'energy', 'key', 'loudness',
                           'mode', 'acousticness', 'instrumentalness',
                           'liveness', 'valence', 'tempo',
                           'duration_ms', 'time_signature']]
rec_features_df.head()
# Out:
#                        id           title first_artist    all_artists  \
# 0  6qZIy961yxJZpFkgsq8Vm2        Jacknife    Belaganas    [Belaganas]
# 1  1Cs748JfTfqzPoZAxBX9Ra  In The Kitchen    Pote Baby    [Pote Baby]
# 2  3nL34IcoPjr7N7CSugioEC        Dior You       Scorey       [Scorey]
# 3  54FJWt8YIA1IHjmUxuDxwi       21C/Delta  Jack Harlow  [Jack Harlow]
# 4  33dN3Nd9aRz4nzha4oIGnX           Godly     Omah Lay     [Omah Lay]
#
#    danceability  energy  key  loudness  mode  acousticness  instrumentalness  \
# 0         0.785   0.559    1    -7.901     1        0.2150          0.000000
# 1         0.881   0.475    1    -8.794     1        0.3030          0.000000
# 2         0.753   0.565   11    -9.142     0        0.0168          0.000000
# 3         0.729   0.588    6    -7.494     0        0.0132          0.000688
# 4         0.640   0.574    5    -8.951     0        0.1380          0.004920
#
#    liveness  valence    tempo  duration_ms  time_signature
# 0     0.109    0.662  140.030       163714               4
# 1     0.229    0.615  146.931       182870               4
# 2     0.122    0.194   97.010       112423               4
# 3     0.147    0.198   97.450       214000               4
# 4     0.342    0.538  198.014       175215               4

# %%
display(rec_features_df)
# Out:
#                         id                                              title  \
# 0   6qZIy961yxJZpFkgsq8Vm2                                           Jacknife
# 1   1Cs748JfTfqzPoZAxBX9Ra                                     In The Kitchen
# 2   3nL34IcoPjr7N7CSugioEC                                           Dior You
# 3   54FJWt8YIA1IHjmUxuDxwi                                          21C/Delta
# 4   33dN3Nd9aRz4nzha4oIGnX                                              Godly
# 5   6L0reMMEHvJsEX7kBo8Dm5                                         Set It Off
# 6   3RaRYw8jgadCrE2q2TjNCX                                          BREAKFAST
# 7   56AMYGJzxBO6p8v0wEe9de         Hot (Remix) [feat. Gunna and Travis Scott]
# 8   5aeaaeKp8fY60CVHAzNbwL                         Cereal (feat. Kenny Mason)
# 9   4NpGQqfAGuIkMVRgVD5VRX                                            Forever
# 10  1HVX9i2RIAIAzPeZrqqRiL                    Smoke From Fire (with The Hics)
# 11  6NsheduXyWbGpCUIAPWr4a                                                IDK
# 12  0evKTZ9MpgVcCd5TBvmeD6                                             On One
# 13  1c5CllrZr45UBhWpIqM332                                        Funny Thing
# 14  3PaovpaWAYcNH6CCBXFfR5                 The Love We Had (Stays On My Mind)
# 15  0wcN45fKhDGWAd0GrWjdYM                                             Golden
# 16  7mjqpvqJx68FS35V33fzoy                                       Sylph Fossil
# 17  4ZAQiu61otvHVveuTsPAUr                             Vibe (If I Back It Up)
# 18  0NQNJDRlvB1x4NzbapbcIg                                        Save Me Now
# 19  5kSh4hhyGRjLitIuNq0Agk                                         You (à la)
# 20  5qXBSsV4uMtyAeL1ZkWPqr                                              READY
# 21  6O1JbI2vepUE3dg5XKkHYi                                            Oh Mama
# 22  6WXRIhPCWf2EJBGxXAWoZm                                               Roar
# 23  1fGt6z8v6GGmnSbNXq7PP2  Love Honey, Love Heartache - Remastered 12" Vo...
# 24  4a44Q09IDiwTP2wu7xYmeA                                              Happy
#
#         first_artist                        all_artists  danceability  energy  \
# 0          Belaganas                        [Belaganas]         0.785   0.559
# 1          Pote Baby                        [Pote Baby]         0.881   0.475
# 2             Scorey                           [Scorey]         0.753   0.565
# 3        Jack Harlow                      [Jack Harlow]         0.729   0.588
# 4           Omah Lay                         [Omah Lay]         0.640   0.574
# 5     Big Daddy Kane                   [Big Daddy Kane]         0.800   0.611
# 6       Bino Rideaux      [Bino Rideaux, BlueBucksClan]         0.721   0.554
# 7         Young Thug  [Young Thug, Travis Scott, Gunna]         0.845   0.631
# 8                IDK            [IDK, JID, Kenny Mason]         0.669   0.617
# 9   Tom The Mail Man                 [Tom The Mail Man]         0.705   0.563
# 10               Bas                    [Bas, The Hics]         0.704   0.542
# 11        Kid Trunks                       [Kid Trunks]         0.771   0.452
# 12       Joyce Wrice       [Joyce Wrice, Freddie Gibbs]         0.683   0.669
# 13        Thundercat                       [Thundercat]         0.586   0.893
# 14          Dru Hill                         [Dru Hill]         0.729   0.623
# 15           Berhana                          [Berhana]         0.671   0.374
# 16        Iglooghost                       [Iglooghost]         0.606   0.705
# 17    Cookiee Kawaii                   [Cookiee Kawaii]         0.778   0.576
# 18       Cat Dealers  [Cat Dealers, Guz Zanotto, Moore]         0.678   0.877
# 19             SACHI                            [SACHI]         0.668   0.693
# 20          P.A.F.F.         [P.A.F.F., Rockstar Payso]         0.682   0.627
# 21      Michael Brun      [Michael Brun, Paul Beaubrun]         0.678   0.746
# 22            Axwell       [Axwell, Sebastian Ingrosso]         0.781   0.704
# 23        Man Friday                       [Man Friday]         0.934   0.599
# 24            AREA21                           [AREA21]         0.654   0.544
#
#     key  loudness  mode  acousticness  instrumentalness  liveness  valence  \
# 0     1    -7.901     1      0.215000          0.000000    0.1090    0.662
# 1     1    -8.794     1      0.303000          0.000000    0.2290    0.615
# 2    11    -9.142     0      0.016800          0.000000    0.1220    0.194
# 3     6    -7.494     0      0.013200          0.000688    0.1470    0.198
# 4     5    -8.951     0      0.138000          0.004920    0.3420    0.538
# 5    10   -13.294     0      0.000359          0.000000    0.2270    0.777
# 6    11   -10.286     1      0.106000          0.000000    0.1370    0.535
# 7     7    -8.206     0      0.188000          0.000000    0.0806    0.545
# 8     9    -8.011     1      0.073300          0.000003    0.1590    0.613
# 9    10    -8.387     0      0.132000          0.000000    0.1070    0.578
# 10    6   -10.523     1      0.174000          0.002670    0.1120    0.521
# 11    1    -7.948     1      0.074800          0.000000    0.2570    0.332
# 12    1    -5.276     0      0.312000          0.000000    0.2130    0.538
# 13    7    -8.772     1      0.827000          0.642000    0.2120    0.650
# 14    7    -4.218     1      0.272000          0.000000    0.0791    0.376
# 15   11   -11.489     0      0.268000          0.018900    0.3240    0.519
# 16    2    -9.676     0      0.147000          0.000728    0.3900    0.285
# 17   10    -8.698     1      0.062700          0.004400    0.1160    0.155
# 18    2    -7.007     0      0.022600          0.009430    0.1930    0.119
# 19    1    -7.386     1      0.026800          0.000204    0.2420    0.478
# 20    7    -5.481     1      0.125000          0.003090    0.2610    0.237
# 21    9    -6.565     1      0.276000          0.010800    0.0905    0.492
# 22    0    -7.276     1      0.000115          0.004540    0.2370    0.650
# 23    0    -6.573     0      0.006310          0.000004    0.0960    0.622
# 24    8    -7.367     1      0.174000          0.000001    0.1440    0.606
#
#       tempo  duration_ms  time_signature
# 0   140.030       163714               4
# 1   146.931       182870               4
# 2    97.010       112423               4
# 3    97.450       214000               4
# 4   198.014       175215               4
# 5   118.764       245960               4
# 6    99.968       184800               4
# 7   111.983       279907               4
# 8   128.202       198863               4
# 9   132.985       187669               4
# 10  148.046       186434               4
# 11  149.964       104281               4
# 12   91.045       205809               4
# 13  140.023       116630               3
# 14  138.239       335867               4
# 15   84.920       119652               4
# 16  135.947       330720               4
# 17   80.027        84000               4
# 18  124.995       142000               4
# 19  126.077       144393               4
# 20  129.956       192000               4
# 21  155.048       154833               4
# 22  124.989       175040               4
# 23  117.753       316587               4
# 24  102.789       171268               4

# %%
rec_features_df.to_json(r'Downloads\rec_json.json')
